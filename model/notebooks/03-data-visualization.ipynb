# %%
import matplotlib.pyplot as plt
import cv2

# Load a generated mask
mask = cv2.imread("../../data/augmented/augmented_mask_vert.png", cv2.IMREAD_GRAYSCALE)

# Visualize
plt.imshow(mask, cmap='gray')
plt.title("Generated Mask")
plt.show()

# %%
# Load a generated mask
mask1 = cv2.imread("../../data/masks/00010_mask.png", cv2.IMREAD_GRAYSCALE)

# Visualize
plt.imshow(mask1, cmap='gray')
plt.title("Generated Mask")
plt.show()
